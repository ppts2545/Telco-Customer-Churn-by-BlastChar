# %% [markdown]
# # 02 Data Overview — Navigation Hub
#
# This analysis has been **split into focused modules** for better readability and maintainability.
#
# ---
#
# ## 📂 Module Structure
#
# ### [01_data_quality.ipynb](01_data_quality.ipynb)
# **Data Quality Check**
# - Data loading and basic info
# - Data type validation (TotalCharges conversion)
# - Missing value detection
# - Duplicate check
# - Export cleaned dataset
#
# ---
#
# ### [02_business_rules.ipynb](02_business_rules.ipynb)
# **Business Logic Validation**
# - Partner/Dependents relationship analysis
# - PhoneService ↔ MultipleLines consistency
# - InternetService dependency checks
# - Cross-service validation rules
# - Summary of business insights
#
# ---
#
# ### [03_univariate_dist.ipynb](03_univariate_dist.ipynb)
# **Univariate Distribution Analysis**
# - Tenure range and churn correlation
# - PaymentMethod categories
# - MonthlyCharges distribution (with visualization)
# - TotalCharges statistics
# - EDA checklist for remaining variables
#
# ---
#
# ## ✅ Workflow
#
# Start with notebook 01 and proceed sequentially:
#
# 1. **Data Quality** → Ensure data is clean and types are correct
# 2. **Business Rules** → Validate logical consistency
# 3. **Univariate Analysis** → Understand individual variable distributions
#
# After completing these, proceed to:
# - `03_Exploratory Data Analysis/` for bivariate/multivariate analysis
# - `04_Modeling/` for predictive modeling
#
# ---
#
# ## 📊 Key Findings Summary
#
# ### Data Quality
# - ✅ TotalCharges converted from object to numeric
# - ✅ No duplicate rows
# - ⚠️ Some missing values in TotalCharges (coerced from spaces)
#
# ### Business Rules
# - ✅ All service dependency rules are consistent
# - ✅ Every customer has at least one service (Phone OR Internet)
# - 📝 361 customers have dependents without partner (17.1%)
# - 📝 1,303 customers have OnlineBackup without OnlineSecurity
# - 📝 1,311 customers have DeviceProtection without OnlineSecurity
#
# ### Distributions
# - Tenure: 0-72 months
# - MonthlyCharges: Multi-modal distribution (different service tiers)
# - PaymentMethod: 4 categories (Electronic check most common)
#
# ---
#
# **Original consolidated notebook archived as:** `02_data_overview_v0.ipynb` (if you need to reference it)
#
# **Next:** Open [01_data_quality.ipynb](01_data_quality.ipynb) to begin the analysis flow
