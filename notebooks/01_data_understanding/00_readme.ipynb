# %% [markdown]
# # 01 Data Understanding - Navigation Hub
#
# > à¹€à¸›à¹‰à¸²à¸«à¸¡à¸²à¸¢ (Objective): à¸—à¸³à¸„à¸§à¸²à¸¡à¹€à¸‚à¹‰à¸²à¹ƒà¸ˆà¹‚à¸„à¸£à¸‡à¸ªà¸£à¹‰à¸²à¸‡à¸‚à¹‰à¸­à¸¡à¸¹à¸¥à¹à¸¥à¸°à¸„à¸§à¸²à¸¡à¹€à¸ªà¸µà¹ˆà¸¢à¸‡à¸”à¹‰à¸²à¸™à¸„à¸¸à¸“à¸ à¸²à¸žà¸à¹ˆà¸­à¸™à¹€à¸‚à¹‰à¸²à¸ªà¸¹à¹ˆà¸‚à¸±à¹‰à¸™à¹€à¸•à¸£à¸µà¸¢à¸¡à¸‚à¹‰à¸­à¸¡à¸¹à¸¥/à¸§à¸´à¹€à¸„à¸£à¸²à¸°à¸«à¹Œà¹€à¸Šà¸´à¸‡à¸¥à¸¶à¸
#
# > Professional intent: establish dataset understanding and baseline data quality before preparation and modeling.
#
# ---
#
# ## Module Structure
#
# ### [01_data_overview.ipynb](01_data_overview.ipynb)
# **à¸ à¸²à¸žà¸£à¸§à¸¡à¸‚à¹‰à¸­à¸¡à¸¹à¸¥à¹à¸¥à¸°à¸šà¸£à¸´à¸šà¸—à¸˜à¸¸à¸£à¸à¸´à¸ˆ | Data overview and business context**
# - Dataset shape and schema
# - Target (Churn) distribution
# - Column definitions and meaning
#
# ### [02_data_quality.ipynb](02_data_quality.ipynb)
# **à¸•à¸£à¸§à¸ˆà¸ªà¸­à¸šà¸„à¸¸à¸“à¸ à¸²à¸žà¸‚à¹‰à¸­à¸¡à¸¹à¸¥ | Data quality profiling**
# - Data type checks and conversion diagnostics
# - Missing values and duplicates
# - Categorical value validation
#
# ---
#
# ## Recommended Workflow
#
# 1. Run **01_data_overview.ipynb**
# 2. Run **02_data_quality.ipynb**
# 3. Continue to **Data Preparation**: [../02_data_preparation/01_business_rules_validation.ipynb](../02_data_preparation/01_business_rules_validation.ipynb)
#
# ---
#
# ## Why This Structure
#
# - **Understanding** = à¸£à¸¹à¹‰à¸ˆà¸±à¸à¸‚à¹‰à¸­à¸¡à¸¹à¸¥à¹à¸¥à¸°à¸„à¸§à¸²à¸¡à¹€à¸ªà¸µà¹ˆà¸¢à¸‡ (know the data and risks)
# - **Preparation** = à¹ƒà¸Šà¹‰ business rules à¹à¸¥à¸°à¸ªà¸£à¹‰à¸²à¸‡ model-ready features
# - **EDA** = à¸§à¸´à¹€à¸„à¸£à¸²à¸°à¸«à¹Œà¸žà¸¤à¸•à¸´à¸à¸£à¸£à¸¡à¹à¸¥à¸°à¸„à¸§à¸²à¸¡à¸ªà¸±à¸¡à¸žà¸±à¸™à¸˜à¹Œà¸‚à¸­à¸‡à¸•à¸±à¸§à¹à¸›à¸£
# - **Modeling/Evaluation** = à¹€à¸—à¸£à¸™à¹‚à¸¡à¹€à¸”à¸¥à¹à¸¥à¸°à¸›à¸£à¸°à¹€à¸¡à¸´à¸™à¸œà¸¥à¹€à¸Šà¸´à¸‡à¹€à¸—à¸„à¸™à¸´à¸„ + à¹€à¸Šà¸´à¸‡à¸˜à¸¸à¸£à¸à¸´à¸ˆ
#
# à¹‚à¸„à¸£à¸‡à¸ªà¸£à¹‰à¸²à¸‡à¸™à¸µà¹‰à¸ªà¸­à¸”à¸„à¸¥à¹‰à¸­à¸‡à¸à¸±à¸š workflow à¹ƒà¸™à¸—à¸µà¸¡ Data/Analytics à¸ˆà¸£à¸´à¸‡ à¹à¸¥à¸°à¹€à¸«à¸¡à¸²à¸°à¸ªà¸³à¸«à¸£à¸±à¸š portfolio à¸ªà¸¡à¸±à¸„à¸£à¸‡à¸²à¸™.
