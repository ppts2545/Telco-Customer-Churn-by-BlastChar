# %% [markdown]
# # 02 Data Preparation - Navigation
#
# Objective: validate business rules, create model-ready features, and export processed dataset.

# %% [markdown]
# ## Notebook Order
#
# 1. [01_business_rules_validation.ipynb](01_business_rules_validation.ipynb)
# 2. [02_feature_engineering.ipynb](02_feature_engineering.ipynb)
#
# Next: [../03_exploratory_analysis/01_univariate_distribution.ipynb](../03_exploratory_analysis/01_univariate_distribution.ipynb)
