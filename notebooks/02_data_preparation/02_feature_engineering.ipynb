# %% [markdown]
# # 02 Feature Engineering
#
# Objective: create reusable features for EDA/modeling and save processed data.

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('../../data/raw/telco_customer_churn.csv')
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')

# %%
# Example engineered feature (already used in your EDA)
df['ChargeGroup'] = pd.qcut(df['MonthlyCharges'], 4)

# Add your next business features here
# df['TenureGroup'] = pd.cut(df['tenure'], bins=[-1, 12, 24, 48, 72], labels=['0-12','13-24','25-48','49-72'])

# %%
df.to_csv('../../data/processed/telco_customer_churn_clean.csv', index=False)
print('Processed data saved to ../../data/processed/telco_customer_churn_clean.csv')

# %% [markdown]
# Next: [../03_exploratory_analysis/01_univariate_distribution.ipynb](../03_exploratory_analysis/01_univariate_distribution.ipynb)
