# %% [markdown]
# # 03 Exploratory Analysis - Navigation
#
# Objective: understand data behavior and churn patterns before modeling.

# %% [markdown]
# ## Notebook Order
#
# 1. [01_univariate_distribution.ipynb](01_univariate_distribution.ipynb)
# 2. [02_eda_charges.ipynb](02_eda_charges.ipynb)
# 3. [03_eda_age_gender.ipynb](03_eda_age_gender.ipynb)
# 4. [04_eda_contract_features.ipynb](04_eda_contract_features.ipynb)
#
# Next: [../05_modeling/00_readme.ipynb](../05_modeling/00_readme.ipynb)
