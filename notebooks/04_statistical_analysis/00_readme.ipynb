# %% [markdown]
# # 04 Statistical Analysis - Navigation
#
# Objective: validate hypotheses with statistical tests before final modeling decisions.

# %% [markdown]
# ## Notebook Order
#
# 1. [01_hypothesis_testing.ipynb](01_hypothesis_testing.ipynb)
#
# Next: [../05_modeling/00_readme.ipynb](../05_modeling/00_readme.ipynb)
