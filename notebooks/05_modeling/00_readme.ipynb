# %% [markdown]
# # 05 Modeling - Navigation
#
# Objective: build baseline and improved churn models, then compare performance.

# %% [markdown]
# ## Notebook Order
#
# 1. [01_model_logistic_regression.ipynb](01_model_logistic_regression.ipynb)
# 2. [02_model_random_forest.ipynb](02_model_random_forest.ipynb)
#
# Next: [../06_evaluation/01_model_evaluation.ipynb](../06_evaluation/01_model_evaluation.ipynb)
